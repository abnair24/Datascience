# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#s=pd.Series(data,index=index)

s = pd.Series(np.random.randn(5),index =['a','b','c','d','e'])
s
# Out:
# a    0.150301
# b   -1.158538
# c    0.498861
# d   -0.741906
# e    1.971437
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {'b':1,'a':2,'c':0}
pd.Series(d)
# Out:
# a    2
# b    1
# c    0
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    2
# b    1
# c    0
# dtype: int64

# %%
pd.Series(5.,index=['a','b','c','d','e'])
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
s[0]
# Out:
# 0.15030096028084952

# %%
s[:3]
# Out:
# a    0.150301
# b   -1.158538
# c    0.498861
# dtype: float64

# %%
ds = {
    'one': pd.Series([1.,2.,3.],index=['a','b','c']),
    'two': pd.Series([1.,2.,3.,4.],index=['a','b','c','d'])
}

df = pd.DataFrame(ds) 
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
d = {'one' : [1., 2., 3., 4.],
     'two' : [4.,3.,2.,1.]}
pd.DataFrame(d)
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
pd.DataFrame(d,index=['a','b','c','d'])
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %%
dates = pd.date_range('20180101',periods=8)
dates
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(8,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-01-01 -0.477290  0.945343  0.554041  0.631368
# 2018-01-02 -1.071325 -1.596192  0.662592 -0.655718
# 2018-01-03  1.622903  0.686159 -0.409385 -0.518725
# 2018-01-04  0.702540 -1.216864 -1.112263  0.930058
# 2018-01-05  0.845214 -0.889671  2.444606 -0.615702
# 2018-01-06  1.863771  2.671751 -0.906921  1.634616
# 2018-01-07 -0.522237 -0.728693 -1.257093 -1.112235
# 2018-01-08  1.280212  0.748765 -0.466469 -0.770191

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                    A         B         C         D
# 2018-01-01 -0.477290  0.945343  0.554041  0.631368
# 2018-01-02 -1.071325 -1.596192  0.662592 -0.655718
# 2018-01-03  1.622903  0.686159 -0.409385 -0.518725
# 2018-01-04  0.702540 -1.216864 -1.112263  0.930058
# 2018-01-05  0.845214 -0.889671  2.444606 -0.615702
# 2018-01-06  1.863771  2.671751 -0.906921  1.634616
# 2018-01-07 -0.522237 -0.728693 -1.257093 -1.112235
# 2018-01-08  1.280212  0.748765 -0.466469 -0.770191>

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2018-01-01  0.631368  0.554041  0.945343 -0.477290
# 2018-01-02 -0.655718  0.662592 -1.596192 -1.071325
# 2018-01-03 -0.518725 -0.409385  0.686159  1.622903
# 2018-01-04  0.930058 -1.112263 -1.216864  0.702540
# 2018-01-05 -0.615702  2.444606 -0.889671  0.845214
# 2018-01-06  1.634616 -0.906921  2.671751  1.863771
# 2018-01-07 -1.112235 -1.257093 -0.728693 -0.522237
# 2018-01-08 -0.770191 -0.466469  0.748765  1.280212

# %%
df.loc[dates[0]]
# Out:
# A   -0.477290
# B    0.945343
# C    0.554041
# D    0.631368
# Name: 2018-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2018-01-01 -0.477290  0.945343
# 2018-01-02 -1.071325 -1.596192
# 2018-01-03  1.622903  0.686159
# 2018-01-04  0.702540 -1.216864
# 2018-01-05  0.845214 -0.889671
# 2018-01-06  1.863771  2.671751
# 2018-01-07 -0.522237 -0.728693
# 2018-01-08  1.280212  0.748765

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2018-01-02 -1.071325  0.662592
# 2018-01-03  1.622903 -0.409385
# 2018-01-05  0.845214  2.444606

# %%
df1 = df[df>0]
df1
# Out:
#                    A         B         C         D
# 2018-01-01       NaN  0.945343  0.554041  0.631368
# 2018-01-02       NaN       NaN  0.662592       NaN
# 2018-01-03  1.622903  0.686159       NaN       NaN
# 2018-01-04  0.702540       NaN       NaN  0.930058
# 2018-01-05  0.845214       NaN  2.444606       NaN
# 2018-01-06  1.863771  2.671751       NaN  1.634616
# 2018-01-07       NaN       NaN       NaN       NaN
# 2018-01-08  1.280212  0.748765       NaN       NaN

# %%
df1.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df1.fillna(value=5.0)
# Out:
#                    A         B         C         D
# 2018-01-01  5.000000  0.945343  0.554041  0.631368
# 2018-01-02  5.000000  5.000000  0.662592  5.000000
# 2018-01-03  1.622903  0.686159  5.000000  5.000000
# 2018-01-04  0.702540  5.000000  5.000000  0.930058
# 2018-01-05  0.845214  5.000000  2.444606  5.000000
# 2018-01-06  1.863771  2.671751  5.000000  1.634616
# 2018-01-07  5.000000  5.000000  5.000000  5.000000
# 2018-01-08  1.280212  0.748765  5.000000  5.000000

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-01 -0.477290  0.945343  0.554041  0.631368
# 2018-01-02 -1.071325 -1.596192  0.662592 -0.655718
# 2018-01-03  1.622903  0.686159 -0.409385 -0.518725
# 2018-01-04  0.702540 -1.216864 -1.112263  0.930058
# 2018-01-05  0.845214 -0.889671  2.444606 -0.615702
# 2018-01-06  1.863771  2.671751 -0.906921  1.634616
# 2018-01-07 -0.522237 -0.728693 -1.257093 -1.112235
# 2018-01-08  1.280212  0.748765 -0.466469 -0.770191

# %%
df.mean()
# Out:
# A    0.530474
# B    0.077575
# C   -0.061362
# D   -0.059566
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2018-01-01    0.413365
# 2018-01-02   -0.665160
# 2018-01-03    0.345238
# 2018-01-04   -0.174132
# 2018-01-05    0.446112
# 2018-01-06    1.315804
# 2018-01-07   -0.905065
# 2018-01-08    0.198079
# Freq: D, dtype: float64

# %%
df["A"].mean()
# Out:
# 0.5304736625804581

# %%
df.loc[:,'A'].mean()
# Out:
# 0.5304736625804581

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D
# 2018-01-01 -0.477290  0.945343  0.554041  0.631368
# 2018-01-02 -1.548615 -0.650849  1.216633 -0.024350
# 2018-01-03  0.074288  0.035310  0.807248 -0.543075
# 2018-01-04  0.776828 -1.181554 -0.305015  0.386983
# 2018-01-05  1.622043 -2.071224  2.139591 -0.228719
# 2018-01-06  3.485814  0.600527  1.232670  1.405897
# 2018-01-07  2.963577 -0.128167 -0.024423  0.293663
# 2018-01-08  4.243789  0.620598 -0.490892 -0.476528

# %%
t = pd.Series(np.random.randn(1000),index = pd.date_range('1/1/2010',periods=1000))

t = t.cumsum()

t.plot()

# %%
t.index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2012-09-17', '2012-09-18', '2012-09-19', '2012-09-20',
#                '2012-09-21', '2012-09-22', '2012-09-23', '2012-09-24',
#                '2012-09-25', '2012-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
dt = pd.DataFrame(np.random.randn(1000,4),index = t.index,columns=['A','B','C','D'])
dt
# Out:
#                    A         B         C         D
# 2010-01-01 -0.985677  0.366863  0.388473 -0.663092
# 2010-01-02  0.157760 -0.465929 -0.735241 -0.250682
# 2010-01-03 -0.033991  0.363566  1.783819  0.447348
# 2010-01-04 -0.591924 -1.518199 -0.349408  0.160944
# 2010-01-05  0.700097 -0.790168 -0.075723  0.711662
# 2010-01-06 -0.991462  0.624305  1.028189  0.809306
# 2010-01-07  0.340100 -0.298626 -0.054653  0.463193
# 2010-01-08 -1.719170  0.917497 -1.138188 -0.537014
# 2010-01-09  0.172789 -1.686624 -2.013146  0.507370
# 2010-01-10 -2.081718  0.206097  0.238545  0.211577
# 2010-01-11  0.231606  0.223888  0.666051  0.953995
# 2010-01-12  0.208568 -0.749045  0.854866 -1.418912
# 2010-01-13 -1.619392  1.526706 -0.388436 -0.894225
# 2010-01-14  1.146064 -0.216287  0.560220 -3.063886
# 2010-01-15 -0.394043  0.080449  0.820114  0.974911
# 2010-01-16  0.272357  2.187752 -0.226063 -2.020441
# 2010-01-17  0.562244 -0.596819 -1.139141 -0.670270
# ...

# %%
dt = dt.cumsum()
dt
# Out:
#                     A          B          C          D
# 2010-01-01  -0.985677   0.366863   0.388473  -0.663092
# 2010-01-02  -0.827917  -0.099066  -0.346768  -0.913774
# 2010-01-03  -0.861908   0.264500   1.437051  -0.466426
# 2010-01-04  -1.453832  -1.253699   1.087644  -0.305482
# 2010-01-05  -0.753735  -2.043868   1.011920   0.406180
# 2010-01-06  -1.745197  -1.419563   2.040109   1.215486
# 2010-01-07  -1.405098  -1.718189   1.985456   1.678679
# 2010-01-08  -3.124267  -0.800691   0.847268   1.141665
# 2010-01-09  -2.951478  -2.487315  -1.165878   1.649035
# 2010-01-10  -5.033196  -2.281218  -0.927333   1.860611
# 2010-01-11  -4.801590  -2.057330  -0.261282   2.814607
# 2010-01-12  -4.593022  -2.806375   0.593584   1.395695
# 2010-01-13  -6.212414  -1.279669   0.205148   0.501470
# 2010-01-14  -5.066350  -1.495957   0.765368  -2.562416
# 2010-01-15  -5.460392  -1.415508   1.585482  -1.587505
# 2010-01-16  -5.188035   0.772244   1.359419  -3.607946
# ...

# %%
dt.plot()
